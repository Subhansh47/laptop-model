# %%
import pandas as pd
import pickle
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn import metrics
from matplotlib import pyplot as plt
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
df=pd.read_csv('laptopprice.csv')
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge, RidgeCV, Lasso
from sklearn.preprocessing import StandardScaler

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
# df.nunique()

# %%
# df.isna().sum()

# %%
# l=LabelEncoder()

# %%
# df['brand']=l.fit_transform(df['brand'])
# df['processor_brand']=l.fit_transform(df['processor_brand'])
# df['processor_name']=l.fit_transform(df['processor_name'])
# df['processor_gnrtn']=l.fit_transform(df['processor_gnrtn'])
# df['ram_gb']=l.fit_transform(df['ram_gb'])
# df['ram_type']=l.fit_transform(df['ram_type'])
# df['ssd']=l.fit_transform(df['ssd'])
# df['hdd']=l.fit_transform(df['hdd'])
# df['os']=l.fit_transform(df['os'])
# df['os_bit']=l.fit_transform(df['os_bit'])
# df['graphic_card_gb']=l.fit_transform(df['graphic_card_gb'])
# df['weight']=l.fit_transform(df['weight'])
# df['warranty']=l.fit_transform(df['warranty'])
# df['Touchscreen']=l.fit_transform(df['Touchscreen'])
# df['msoffice']=l.fit_transform(df['msoffice'])

# %%
df['rate'] = df['rating'].apply(lambda x: int(x.split(' ')[0]))
df.drop(['Number of Ratings','rating','Number of Reviews'],axis=1,inplace=True)

# %%
categorical_features = df.select_dtypes(include=['object'])

# %%
categorical_features.columns
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice'],
#       dtype='object')

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
X=df.drop('Price',axis=1)
y=df['Price']

# %%
# X

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# y_test

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()

# %%
# X

# %%
# dt.fit(X_train,y_train)

# %%
# y_pred=dt.predict(X_test)

# %%
# dt.score(X_train,y_train)

# %%
# dp=df['rate'] = df['rate'].apply(lambda x: int(x.split(' ')[0]))
# df.drop(['Number of Ratings','rating','Number of Reviews','rate'],axis=1,inplace=True)

# %%
cp=Pipeline(steps=[
    ("onehot",OneHotEncoder(handle_unknown='ignore'))
])
# ohe=OneHotEncoder()
# ohe.fit(X[c/ategorical_features.columns])
# column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),categorical_features.columns),remainder='passthrough')

# %%
cp
# Out:
# Pipeline(steps=[('onehot', OneHotEncoder(handle_unknown='ignore'))])

# %%
pr=ColumnTransformer(
    [
        ("categorical",cp,['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
       'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
       'weight', 'warranty', 'Touchscreen', 'msoffice'])
    ]
)

# %%
pr.fit(df)
# Out:
# ColumnTransformer(transformers=[('categorical',
#                                  Pipeline(steps=[('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  ['brand', 'processor_brand', 'processor_name',
#                                   'processor_gnrtn', 'ram_gb', 'ram_type',
#                                   'ssd', 'hdd', 'os', 'os_bit',
#                                   'graphic_card_gb', 'weight', 'warranty',
#                                   'Touchscreen', 'msoffice'])])

# %%
pr
# Out:
# ColumnTransformer(transformers=[('categorical',
#                                  Pipeline(steps=[('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  ['brand', 'processor_brand', 'processor_name',
#                                   'processor_gnrtn', 'ram_gb', 'ram_type',
#                                   'ssd', 'hdd', 'os', 'os_bit',
#                                   'graphic_card_gb', 'weight', 'warranty',
#                                   'Touchscreen', 'msoffice'])])

# %%
# pipe=make_pipeline(pr,Lasso(alpha=1.3))
pipe=make_pipeline(pr,Ridge())
# pipe=make_pipeline(pr,Lasso(alpha=1.3))
# pipe=make_pipeline(pr,Lasso(alpha=1.3))

# %%
pipe
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('categorical',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['brand', 'processor_brand',
#                                                    'processor_name',
#                                                    'processor_gnrtn', 'ram_gb',
#                                                    'ram_type', 'ssd', 'hdd',
#                                                    'os', 'os_bit',
#                                                    'graphic_card_gb', 'weight',
#                                                    'warranty', 'Touchscreen',
#                                                    'msoffice'])])),
#                 ('ridge', Ridge())])

# %%
data = pd.read_csv("laptopPrice.csv")

# %%
data.drop(columns=['rating','Number of Ratings','Number of Reviews'],inplace=True)

# %%
x=data.drop(columns='Price')
y=data['Price']

# %%
X_train, X_test, y_train, y_test = train_test_split( x, y, test_size=0.33, random_state=42)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('categorical',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['brand', 'processor_brand',
#                                                    'processor_name',
#                                                    'processor_gnrtn', 'ram_gb',
#                                                    'ram_type', 'ssd', 'hdd',
#                                                    'os', 'os_bit',
#                                                    'graphic_card_gb', 'weight',
#                                                    'warranty', 'Touchscreen',
#                                                    'msoffice'])])),
#                 ('ridge', Ridge())])

# %%
pipe.score(X_train,y_train)
# Out:
# 0.8065490207111958

# %%
pipe.score(X_test,y_test)
# Out:
# 0.7360616993085507

# %%
pipe
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('categorical',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['brand', 'processor_brand',
#                                                    'processor_name',
#                                                    'processor_gnrtn', 'ram_gb',
#                                                    'ram_type', 'ssd', 'hdd',
#                                                    'os', 'os_bit',
#                                                    'graphic_card_gb', 'weight',
#                                                    'warranty', 'Touchscreen',
#                                                    'msoffice'])])),
#                 ('ridge', Ridge())])

# %%
pickle.dump(pipe,open('pipemodel.pkl','wb'))

# %%
import pandas as pd

# Assuming these are the input features in the given order
new_data = pd.DataFrame([['APPLE', 'Intel', 'Core i3', '11th', '2 GB', 'DDR3', '128 GB', '1024 GB', 'DOS', '64-bit', '4 GB', 'Casual', 'No warranty', 'Ye', 'Yes']],
                        columns=['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
       'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
       'weight', 'warranty', 'Touchscreen', 'msoffice'])

# Make sure to pass the new_data through the pipeline's predict function
predicted_price = pipe.predict(new_data)

print("Predicted Price: {:.2f}".format(predicted_price[0]))
# Out:
# Predicted Price: 167911.11

# %%
# pipe.predict(['ASUS',	'Intel',	'Core i3',	'10th'	,'4 GB'	,'DDR4',	'0 GB'	,'1024 GB',	'Windows',	'64-bit',	'0 GB',	'Casual',	'No warranty',	'No',	'No'	,'34649'	,'2 stars,'	'3'	,'0'])

# %%
# import pandas as pd
# import pickle
# from sklearn.preprocessing import LabelEncoder, OneHotEncoder
# from sklearn.model_selection import train_test_split
# from sklearn import metrics
# from matplotlib import pyplot as plt
# from sklearn.compose import ColumnTransformer
# from sklearn.linear_model import Lasso
# from sklearn.pipeline import Pipeline, make_pipeline

# df = pd.read_csv('laptopprice.csv')

# categorical_features = df.select_dtypes(include=['object'])

# cp = Pipeline(steps=[("onehot", OneHotEncoder(handle_unknown='ignore'))])

# pr = ColumnTransformer(
#     [
#         ("categorical", cp, ['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#                              'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#                              'weight', 'warranty', 'Touchscreen', 'msoffice'])
#     ]
# )

# pr.fit(df)

# pipe = make_pipeline(pr, Lasso(alpha=0.01))  # Set alpha for regularization

# data = pd.read_csv("laptopPrice.csv")
# data.drop(columns=['rating', 'Number of Ratings', 'Number of Reviews'], inplace=True)
# x = data.drop(columns='Price')
# y = data['Price']

# pipe.fit(x, y)

# pipe.score(x, y)

# pickle.dump(pipe, open('pipemodel.pkl', 'wb'))

# # Assuming these are the input features in the given order
# new_data = pd.DataFrame([['Lenovo'	,'Intel',	'Core i3',	'10th',	'4 GB',	'DDR4',	'0 GB',	'1024 GB',	'Windows',	'64-bit',	'0 GB',	'Casual',	'No warranty',	'No',	'No']],
#                         columns=['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#                                  'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#                                  'weight', 'warranty', 'Touchscreen', 'msoffice'])

# # Make sure to pass the new_data through the pipeline's predict function
# predicted_price = pipe.predict(new_data)

# print("Predicted Price: {:.2f}".format(predicted_price[0]))
